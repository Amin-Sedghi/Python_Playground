# %%
import random


options=['Rock','Paper','Scissor']
num_player_won= 0
num_computer_won=0


print(f"Welcome to the game. Whoever reaches 3 point will win the game. Let's start.\n")

while num_player_won < 3 and num_computer_won < 3:

  player_guess = int(input('Chosse between Rock,Paper,Scissor (for Rock enter 0 , for Paper enter 1 and for scissor enter 2) and press enter.\n'))

  computer_guess=random.randint(0 ,2)
  if computer_guess == 0:
    print(f'The computer chose Rock\n')
  elif computer_guess == 1:
    print(f'The computer chose Paper\n')
  else:
    print(f'The computer chose Scissor\n')


  if player_guess not in [0,1,2]:
    print(f'Invalid input. Please try again\n')
    continue
  if player_guess == computer_guess:
    print(f"Draw. Let's continue\n")
    continue
  if player_guess == 0 and computer_guess == 2:
    print(f'You won this round.\n')
    num_player_won += 1
  elif player_guess == 1 and computer_guess == 0:
    print(f'You won this round.\n')
    num_player_won += 1
  elif player_guess == 2 and computer_guess == 1:
    print(f'You won this round.\n')
    num_player_won += 1
  else:
    print('The computer won this round\n')
    num_computer_won += 1

if num_player_won == 3:
  print(f'Congratulations. You won the game\n')
else:
  print(f'Game over\n')
print(f'Goodbye\n')
